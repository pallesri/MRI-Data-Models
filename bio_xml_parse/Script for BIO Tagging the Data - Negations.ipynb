# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
import nltk
from nltk.tokenize import TreebankWordTokenizer as twt

# %%
from scipy.spatial.distance import cdist

# %%
import re
import itertools
import math

# %%
import os.path
from os import path

# %%
from ast import literal_eval

# %% [markdown]
# **Read a Data set**

# %%
data = pd.read_excel('bio_df_final.xlsx')

print (data.shape)
# Out:
# (11871, 5)

# %%
data.head(3)
# Out:
#     sid  oidx                                          sentences neg_scopes  \
# 0  S1.1     0  Induction of NF-KB during monocyte differentia...         []
# 1  S1.2     1  The production of human immunodeficiency virus...         []
# 2  S1.3     2  Electrophoretic mobility shift assays and Sout...         []
#
#   spec_scopes
# 0          []
# 1          []
# 2          []

# %%
data['neg_scopes'] = data['neg_scopes'].apply(lambda x: literal_eval(x))
data['spec_scopes'] = data['spec_scopes'].apply(lambda x: literal_eval(x))

# %%
data.index
# Out:
# RangeIndex(start=0, stop=11871, step=1)

# %%
scope = "not in the S1 and S1' subsites of cathepsin D"
scope_new = ' '.join(twt().tokenize(scope))

len_scope = len(twt().tokenize(scope_new))

bigs = "From information available in the literature on the substrate \
specificity of the three enzymes, it is clear that a cysteine is not accepted \
in any of the S2, S1, S1', and S2' subsites of cathepsin B and L, and not in the S1 and S1' subsites of cathepsin D."
bigs_tokens = twt().tokenize(bigs)
bigs_new = ' '.join(bigs_tokens)

print (bigs_new)
print (scope_new)
remains = bigs_new.replace(scope_new,'')
len_remains= len(twt().tokenize(remains))

print (remains, len_remains)

label_scope = []
for i in range(len_scope):
    if i==0:
        label_scope.append('B-Negation')
    else:
        label_scope.append('I-Negation')
        
bio = ' '.join(label_scope)
print (bio)

label_remains = []
for i in range(len_remains):
    label_remains.append('O')
    
others = ' '.join(label_remains)
print (others)

temps = bigs_new.replace(scope_new, bio)
print (temps)

temps_tokens = twt().tokenize(temps)
annotated_string = ['O' if (elem not in ['B-Negation', 'I-Negation']) else elem for elem in temps_tokens]
#print (annotated_string)

# annotated_string = temps.replace(remains.strip(), others)

ann_df = pd.DataFrame()
ann_df['token'] = bigs_tokens
ann_df['tag'] = annotated_string
ann_df
# Out:
# From information available in the literature on the substrate specificity of the three enzymes , it is clear that a cysteine is not accepted in any of the S2 , S1 , S1 ' , and S2 ' subsites of cathepsin B and L , and not in the S1 and S1 ' subsites of cathepsin D .
# not in the S1 and S1 ' subsites of cathepsin D
# From information available in the literature on the substrate specificity of the three enzymes , it is clear that a cysteine is not accepted in any of the S2 , S1 , S1 ' , and S2 ' subsites of cathepsin B and L , and  . 47
# B-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation
# O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# From information available in the literature on the substrate specificity of the three enzymes , it is clear that a cysteine is not accepted in any of the S2 , S1 , S1 ' , and S2 ' subsites of cathepsin B and L , and B-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation I-Negation .
#           token         tag
# 0          From           O
# 1   information           O
# 2     available           O
# 3            in           O
# 4           the           O
# 5    literature           O
# 6            on           O
# 7           the           O
# 8     substrate           O
# 9   specificity           O
# 10           of           O
# 11          the           O
# 12        three           O
# 13      enzymes           O
# 14            ,           O
# 15           it           O
# 16           is           O
# 17        clear           O
# 18         that           O
# 19            a           O
# 20     cysteine           O
# 21           is           O
# 22          not           O
# 23     accepted           O
# 24           in           O
# 25          any           O
# 26           of           O
# 27          the           O
# 28           S2           O
# 29            ,           O
# 30           S1           O
# 31            ,           O
# 32           S1           O
# 33            '           O
# 34            ,           O
# 35          and           O
# 36           S2           O
# 37            '           O
# 38     subsites           O
# 39           of           O
# 40    cathepsin           O
# 41            B           O
# 42          and           O
# 43            L           O
# 44            ,           O
# 45          and           O
# 46          not  B-Negation
# 47           in  I-Negation
# 48          the  I-Negation
# 49           S1  I-Negation
# 50          and  I-Negation
# 51           S1  I-Negation
# 52            '  I-Negation
# 53     subsites  I-Negation
# 54           of  I-Negation
# 55    cathepsin  I-Negation
# 56            D  I-Negation
# 57            .           O

# %%
def convert_bio(sent,scope_list):
    bigs_tokens = twt().tokenize(sent)
    bigs_new = ' '.join(bigs_tokens)
    
    if (len(scope_list) == 0):
        annotated_string = ['O' for elem in bigs_tokens]
    else:
        for scope in scope_list:
            scope_new = ' '.join(twt().tokenize(scope))
            len_scope = len(twt().tokenize(scope_new))

#             print (bigs_new)
#             print (scope_new)
            remains = bigs_new.replace(scope_new,'')
            len_remains= len(twt().tokenize(remains))

#            print (remains, len_remains)

            label_scope = []
            for i in range(len_scope):
                if i==0:
                    label_scope.append('B-Negation')
                else:
                    label_scope.append('I-Negation')

            bio = ' '.join(label_scope)
#            print (bio)

            label_remains = []
            for i in range(len_remains):
                label_remains.append('O')

            others = ' '.join(label_remains)
#            print (others)

            temps = bigs_new.replace(scope_new, bio)
#            print (scope_new)
            #print (bio)
#            print (bigs_new)    
#            print (temps)
            bigs_new = temps
            temps_tokens = twt().tokenize(temps)
            annotated_string = ['O' if (elem not in ['B-Negation', 'I-Negation']) else elem for elem in temps_tokens]
#            print (temps_tokens)
#            print (annotated_string)

            # annotated_string = temps.replace(remains.strip(), others)

    ann_df = pd.DataFrame()
    ann_df['token'] = twt().tokenize(sent)
    ann_df['tag'] = annotated_string
    
    return ann_df

# %%
s1 = "not in the S1 and S1' subsites of cathepsin D"
s2 = "a cysteine is not accepted in any of the S2, S1, S1'"
sbig = "From information available in the literature on the substrate \
specificity of the three enzymes, it is clear that a cysteine is not accepted \
in any of the S2, S1, S1', and S2' subsites of cathepsin B and L, and not in the S1 and S1' subsites of cathepsin D."

#convert_bio("i dont (know), i love you too.", ['i dont', 'you too'])
convert_bio(sbig, [s1, s2])
# Out:
#           token         tag
# 0          From           O
# 1   information           O
# 2     available           O
# 3            in           O
# 4           the           O
# 5    literature           O
# 6            on           O
# 7           the           O
# 8     substrate           O
# 9   specificity           O
# 10           of           O
# 11          the           O
# 12        three           O
# 13      enzymes           O
# 14            ,           O
# 15           it           O
# 16           is           O
# 17        clear           O
# 18         that           O
# 19            a  B-Negation
# 20     cysteine  I-Negation
# 21           is  I-Negation
# 22          not  I-Negation
# 23     accepted  I-Negation
# 24           in  I-Negation
# 25          any  I-Negation
# 26           of  I-Negation
# 27          the  I-Negation
# 28           S2  I-Negation
# 29            ,  I-Negation
# 30           S1  I-Negation
# 31            ,  I-Negation
# 32           S1  I-Negation
# 33            '  I-Negation
# 34            ,           O
# 35          and           O
# 36           S2           O
# 37            '           O
# 38     subsites           O
# 39           of           O
# 40    cathepsin           O
# 41            B           O
# 42          and           O
# 43            L           O
# 44            ,           O
# 45          and           O
# 46          not  B-Negation
# 47           in  I-Negation
# 48          the  I-Negation
# 49           S1  I-Negation
# 50          and  I-Negation
# 51           S1  I-Negation
# 52            '  I-Negation
# 53     subsites  I-Negation
# 54           of  I-Negation
# 55    cathepsin  I-Negation
# 56            D  I-Negation
# 57            .           O

# %%
data.head()
# Out:
#     sid  oidx                                          sentences  \
# 0  S1.1     0  Induction of NF-KB during monocyte differentia...
# 1  S1.2     1  The production of human immunodeficiency virus...
# 2  S1.3     2  Electrophoretic mobility shift assays and Sout...
# 3  S1.4     3  PMA treatment, and not retinoic acid treatment...
# 4  S1.5     4  In nuclear extracts from monocytes or macropha...
#
#                                         neg_scopes spec_scopes
# 0                                               []          []
# 1                                               []          []
# 2                                               []          []
# 3  [not retinoic acid treatment of the U937 cells]          []
# 4                                               []          []

# %%
#data['annotations'] = data.apply(lambda x: convert_bio(x.sentences, x.neg_scopes), axis=1)

# %%
data.head()
# Out:
#     sid  oidx                                          sentences  \
# 0  S1.1     0  Induction of NF-KB during monocyte differentia...
# 1  S1.2     1  The production of human immunodeficiency virus...
# 2  S1.3     2  Electrophoretic mobility shift assays and Sout...
# 3  S1.4     3  PMA treatment, and not retinoic acid treatment...
# 4  S1.5     4  In nuclear extracts from monocytes or macropha...
#
#                                         neg_scopes spec_scopes
# 0                                               []          []
# 1                                               []          []
# 2                                               []          []
# 3  [not retinoic acid treatment of the U937 cells]          []
# 4                                               []          []

# %%
snts = data['sentences'].to_list()
ngs = data['neg_scopes'].to_list()
ngs

negation_bio = []
for s,n in zip(snts,ngs):
    negation_bio.append((convert_bio(s,n)))

# %%
negation_bio
# Out:
# [              token tag
#  0         Induction   O
#  1                of   O
#  2             NF-KB   O
#  3            during   O
#  4          monocyte   O
#  5   differentiation   O
#  6                by   O
#  7               HIV   O
#  8              type   O
#  9                 1   O
#  10        infection   O
#  11                .   O,                token tag
#  0                The   O
#  1         production   O
#  2                 of   O
#  3              human   O
#  4   immunodeficiency   O
#  5              virus   O
#  6               type   O
#  7                  1   O
#  8                  (   O
#  9              HIV-1   O
#  10                 )   O
#  11           progeny   O
#  12               was   O
#  13          followed   O
#  14                in   O
#  15               the   O
#  16              U937   O
#  17      promonocytic   O
#  18              cell   O
#  19              line   O
#  20             after   O
#  21       stimulation   O
#  22            either   O
#  23              with   O
#  24          retinoic   O
#  25              acid   O
#  26                or   O
#  27               PMA   O
#  28                 ,   O
#  29               and   O
#  30                in   O
#  31          purified   O
#  32             human   O
#  33         monocytes   O
#  34               and   O
#  35       macrophages   O
#  36                 .   O,               token tag
#  0   Electrophoretic   O
#  1          mobility   O
#  2             shift   O
#  3            assays   O
#  4               and   O
#  5      Southwestern   O
#  6          blotting   O
#  7       experiments   O
#  8              were   O
#  9              used   O
#  10               to   O
#  11           detect   O
#  12              the   O
#  13          binding   O
#  14               of   O
#  15         cellular   O
#  16  transactivation   O
#  17           factor   O
#  18            NF-KB   O
#  19               to   O
#  20              the   O
#  21           double   O
#  22        repeat-KB   O
#  23         enhancer   O
#  24         sequence   O
#  25          located   O
#  26               in   O
#  27              the   O
#  28             long   O
#  29         terminal   O
#  30           repeat   O
#  31                .   O,          token         tag
#  0          PMA           O
#  1    treatment           O
#  2            ,           O
#  3          and           O
#  4          not  B-Negation
#  5     retinoic  I-Negation
#  6         acid  I-Negation
#  7    treatment  I-Negation
#  8           of  I-Negation
#  9          the  I-Negation
#  10        U937  I-Negation
#  11       cells  I-Negation
#  12        acts           O
#  13          in           O
#  14    inducing           O
#  15       NF-KB           O
#  16  expression           O
#  17          in           O
#  18         the           O
#  19      nuclei           O
#  20           .           O,           token tag
#  0            In   O
#  1       nuclear   O
#  2      extracts   O
#  3          from   O
#  4     monocytes   O
#  5            or   O
#  6   macrophages   O
#  7             ,   O
#  8     induction   O
#  9            of   O
#  10        NF-KB   O
#  11     occurred   O
#  12         only   O
#  13           if   O
#  14          the   O
#  15        cells   O
#  16         were   O
#  17   previously   O
#  18     infected   O
#  19         with   O
#  20        HIV-1   O
#  21            .   O,           token         tag
#  0          When           O
#  1          U937           O
#  2         cells           O
#  3          were           O
#  4      infected           O
#  5          with           O
#  6         HIV-1           O
#  7             ,           O
#  8            no  B-Negation
#  9     induction  I-Negation
#  10           of  I-Negation
#  11        NF-KB  I-Negation
#  12       factor  I-Negation
#  13          was  I-Negation
#  14     detected  I-Negation
#  15            ,           O
#  16      whereas           O
#  17         high           O
#  18        level           O
#  19           of           O
#  20      progeny           O
#  21      virions           O
#  22          was           O
#  23     produced           O
#  24            ,           O
#  25   suggesting           O
#  26         that           O
#  27         this           O
#  28       factor           O
#  29          was           O
#  30          not           O
#  31     required           O
#  32          for           O
#  33        viral           O
#  34  replication           O
#  35            .           O,                          token tag
#  0                        These   O
#  1                      results   O
#  2                     indicate   O
#  3                         that   O
#  4                           in   O
#  5                    monocytic   O
#  6                         cell   O
#  7                      lineage   O
#  8                            ,   O
#  9                        HIV-1   O
#  10                       could   O
#  11                       mimic   O
#  12                        some   O
#  13  differentiation/activation   O
#  14                     stimuli   O
#  15                    allowing   O
#  16                     nuclear   O
#  17                       NF-KB   O
#  18                  expression   O
#  19                           .   O,               token tag
#  0          Positive   O
#  1               and   O
#  2          negative   O
#  3        regulation   O
#  4                of   O
#  5    immunoglobulin   O
#  6              gene   O
#  7        expression   O
#  8                by   O
#  9                 a   O
#  10            novel   O
#  11  B-cell-specific   O
#  12         enhancer   O
#  13          element   O
#  14                .   O,               token tag
#  0                 A   O
#  1               new   O
#  2   B-cell-specific   O
#  3          enhancer   O
#  4           element   O
#  5               has   O
#  6              been   O
#  7        identified   O
#  8                 3   O
#  9                 '   O
#  10               of   O
#  11               E4   O
#  12              and   O
#  13              the   O
#  14      octamerlike   O
#  15           motifs   O
#  16               in   O
#  17              the   O
#  18            human   O
#  19   immunoglobulin   O
#  20      heavy-chain   O
#  21             gene   O
#  22         enhancer   O
#  23                .   O,                 token         tag
#  0              Tandem           O
#  1              copies           O
#  2                  of           O
#  3                this           O
#  4               67-bp           O
#  5           MnlI-AluI           O
#  6            fragment           O
#  7                   ,           O
#  8                when           O
#  9               fused           O
#  10                 to           O
#  11                the           O
#  12    chloramphenicol           O
#  13  acetyltransferase           O
#  14               gene           O
#  15             driven           O
#  16                 by           O
#  17                the           O
#  18         conalbumin           O
#  19           promoter           O
#  20                  ,           O
#  21         stimulated           O
#  22      transcription           O
#  23                 in           O
#  24                  B           O
#  25              cells           O
#  26                but           O
#  27                not  B-Negation
#  28                 in  I-Negation
#  29             Jurkat  I-Negation
#  30                  T  I-Negation
#  31              cells  I-Negation
#  32                 or  I-Negation
#  33               HeLa  I-Negation
#  34              cells  I-Negation
#  35                  .           O,               token tag
#  0      Footprinting   O
#  1          analysis   O
#  2          revealed   O
#  3              that   O
#  4               the   O
#  5         identical   O
#  6          sequence   O
#  7   CCGAAACTGAAAAGG   O
#  8                 ,   O
#  9        designated   O
#  10               E6   O
#  11                ,   O
#  12              was   O
#  13        protected   O
#  14               by   O
#  15          nuclear   O
#  16         extracts   O
#  17             from   O
#  18                B   O
#  19            cells   O
#  20                ,   O
#  21                T   O
#  22            cells   O
#  23                ,   O
#  24               or   O
#  25             HeLa   O
#  26            cells   O
#  27                .   O,               token tag
#  0               Gel   O
#  1          mobility   O
#  2             shift   O
#  3            assays   O
#  4             using   O
#  5                 a   O
#  6         synthetic   O
#  7                E6   O
#  8             motif   O
#  9          detected   O
#  10                a   O
#  11  B-cell-specific   O
#  12          complex   O
#  13               in   O
#  14         addition   O
#  15               to   O
#  16                a   O
#  17       ubiquitous   O
#  18             band   O
#  19            found   O
#  20             also   O
#  21               in   O
#  22                T   O
#  23            cells   O
#  24              and   O
#  25             HeLa   O
#  26            cells   O
#  27                .   O,             token         tag
#  0              In           O
#  1       agreement           O
#  2            with           O
#  3             the           O
#  4         results           O
#  5              of           O
#  6             gel           O
#  7     retardation           O
#  8          assays           O
#  9               ,           O
#  10         tandem           O
#  11         copies           O
#  12             of           O
#  13            the           O
#  14             E6           O
#  15          motif           O
#  16     stimulated           O
#  17  transcription           O
#  18             in           O
#  19          ARH77           O
#  20            and           O
#  21           Raji           O
#  22          cells           O
#  23            but           O
#  24            not  B-Negation
#  25             in  I-Negation
#  26         Jurkat  I-Negation
#  27             or  I-Negation
#  28           HeLa  I-Negation
#  29          cells  I-Negation
#  30              .           O,           token tag
#  0   Furthermore   O
#  1             ,   O
#  2             a   O
#  3        mutant   O
#  4            E6   O
#  5         motif   O
#  6          lost   O
#  7          both   O
#  8            in   O
#  9         vitro   O
#  10      binding   O
#  11     activity   O
#  12          and   O
#  13           in   O
#  14         vivo   O
#  15     enhancer   O
#  16     activity   O
#  17            .   O,               token         tag
#  0                In           O
#  1          striking           O
#  2          contrast           O
#  3                to           O
#  4               the           O
#  5             mouse           O
#  6                Ig           O
#  7       heavy-chain           O
#  8          enhancer           O
#  9                 ,           O
#  10               in           O
#  11            which           O
#  12              the           O
#  13          octamer           O
#  14            motif           O
#  15             acts           O
#  16               as           O
#  17                a           O
#  18  B-cell-specific           O
#  19         enhancer           O
#  20          element           O
#  21                ,           O
#  22              the           O
#  23            human           O
#  24         enhancer           O
#  25         contains           O
#  26               an           O
#  27      octamerlike           O
#  28         sequence           O
#  29             with           O
#  30              one           O
#  31             base           O
#  32     substitution           O
#  33            which           O
#  34            bound           O
#  35  octamer-binding           O
#  36         proteins           O
#  37             with           O
#  38             only           O
#  39             very           O
#  40              low           O
#  41         affinity           O
#  42              and           O
#  43           showed           O
#  44               no  B-Negation
#  45         enhancer  I-Negation
#  46         activity  I-Negation
#  47               of  I-Negation
#  48              its  I-Negation
#  49              own  I-Negation
#  50                .           O,             token tag
#  0   Interestingly   O
#  1               ,   O
#  2             the   O
#  3       MnlI-AluI   O
#  4        fragment   O
#  5           could   O
#  6        suppress   O
#  7             the   O
#  8     basal-level   O
#  9        activity   O
#  10             of   O
#  11            the   O
#  12     conalbumin   O
#  13       promoter   O
#  14             in   O
#  15           both   O
#  16         Jurkat   O
#  17            and   O
#  18           HeLa   O
#  19          cells   O
#  20              .   O,         token         tag
#  0    Moreover           O
#  1           ,           O
#  2      simian           O
#  3       virus           O
#  4          40           O
#  5    enhancer           O
#  6    activity           O
#  7         was           O
#  8     blocked           O
#  9          by           O
#  10        the           O
#  11  MnlI-AluI           O
#  12   fragment           O
#  13         in           O
#  14       HeLa           O
#  15      cells           O
#  16        but           O
#  17        not  B-Negation
#  18         in  I-Negation
#  19          B  I-Negation
#  20      cells  I-Negation
#  21          .           O,          token tag
#  0         Thus   O
#  1            ,   O
#  2          the   O
#  3        novel   O
#  4     enhancer   O
#  5      element   O
#  6   identified   O
#  7           in   O
#  8         this   O
#  9        study   O
#  10          is   O
#  11    probably   O
#  12           a   O
#  13      target   O
#  14        site   O
#  15         for   O
#  16        both   O
#  17    positive   O
#  18         and   O
#  19    negative   O
#  20     factors   O
#  21           .   O,           token tag
#  0           The   O
#  1            NF   O
#  2         kappa   O
#  3             B   O
#  4   independent   O
#  5    cis-acting   O
#  6     sequences   O
#  7            in   O
#  8         HIV-1   O
#  9           LTR   O
#  10   responsive   O
#  11           to   O
#  12       T-cell   O
#  13   activation   O
#  14            .   O,             token tag
#  0             The   O
#  1            rate   O
#  2              of   O
#  3   transcription   O
#  4      initiation   O
#  5        directed   O
#  6              by   O
#  7             the   O
#  8            long   O
#  9        terminal   O
#  10         repeat   O
#  11              (   O
#  12            LTR   O
#  13              )   O
#  14             of   O
#  15          HIV-1   O
#  16      increases   O
#  17             in   O
#  18       response   O
#  19             to   O
#  20      mitogenic   O
#  21        stimuli   O
#  22             of   O
#  23              T   O
#  24          cells   O
#  25              .   O,             token tag
#  0            Here   O
#  1              we   O
#  2            show   O
#  3            that   O
#  4             the   O
#  5        response   O
#  6              of   O
#  7             the   O
#  8           HIV-1   O
#  9             LTR   O
#  10            may   O
#  11             be   O
#  12       governed   O
#  13             by   O
#  14            two   O
#  15    independent   O
#  16      sequences   O
#  17        located   O
#  18              5   O
#  19              '   O
#  20             to   O
#  21            the   O
#  22           site   O
#  23             of   O
#  24  transcription   O
#  25     initiation   O
#  26      sequences   O
#  27           that   O
#  28           bind   O
#  29         either   O
#  30         NFAT-1   O
#  31             or   O
#  32             NF   O
#  33          kappa   O
#  34              B   O
#  35              .   O,            token         tag
#  0            The           O
#  1           rate           O
#  2             of           O
#  3   LTR-directed           O
#  4           gene           O
#  5     expression           O
#  6      increased           O
#  7             in           O
#  8       response           O
#  9             to           O
#  10     treatment           O
#  11          with           O
#  12        either           O
#  13             a           O
#  14       phorbol           O
#  15         ester           O
#  16            or           O
#  17         tumor           O
#  18      necrosis           O
#  19        factor           O
#  20         alpha           O
#  21            if           O
#  22        either           O
#  23           the           O
#  24        NFAT-1           O
#  25            or           O
#  26            NF           O
#  27         kappa           O
#  28             B           O
#  29       binding           O
#  30         sites           O
#  31          were           O
#  32       deleted           O
#  33             ,           O
#  34           but           O
#  35        failed  B-Negation
#  36            to  I-Negation
#  37       respond  I-Negation
#  38            to  I-Negation
#  39         these  I-Negation
#  40     mitogenic  I-Negation
#  41       stimuli  I-Negation
#  42            if  I-Negation
#  43          both  I-Negation
#  44     sequences  I-Negation
#  45          were  I-Negation
#  46        absent  I-Negation
#  47             .           O,          token tag
#  0          The   O
#  1        HIV-1   O
#  2       mutant   O
#  3        virus   O
#  4   containing   O
#  5         both   O
#  6           NF   O
#  7        kappa   O
#  8            B   O
#  9          and   O
#  10      NFAT-1   O
#  11    deletion   O
#  12         was   O
#  13        able   O
#  14          to   O
#  15   replicate   O
#  16    although   O
#  17          at   O
#  18           a   O
#  19        much   O
#  20   decreased   O
#  21      growth   O
#  22        rate   O
#  23           ,   O
#  24       while   O
#  25         the   O
#  26    deletion   O
#  27          of   O
#  28      NFAT-1   O
#  29       alone   O
#  30   increased   O
#  31         the   O
#  32       viral   O
#  33      growth   O
#  34        rate   O
#  35          in   O
#  36      Jurkat   O
#  37       cells   O
#  38           .   O,           token         tag
#  0       Neither  B-Negation
#  1      deletion  I-Negation
#  2            of  I-Negation
#  3            NF  I-Negation
#  4         kappa  I-Negation
#  5             B  I-Negation
#  6           nor  I-Negation
#  7      deletion  I-Negation
#  8            of  I-Negation
#  9        NFAT-1  I-Negation
#  10    decreased  I-Negation
#  11   activation  I-Negation
#  12           of  I-Negation
#  13        viral  I-Negation
#  14  replication  I-Negation
#  15           by  I-Negation
#  16      phorbol  I-Negation
#  17        ester  I-Negation
#  18            .           O,          token tag
#  0     Specific   O
#  1    depletion   O
#  2           of   O
#  3          the   O
#  4       B-cell   O
#  5   population   O
#  6      induced   O
#  7           by   O
#  8     aberrant   O
#  9   expression   O
#  10          of   O
#  11       human   O
#  12  interferon   O
#  13  regulatory   O
#  14      factor   O
#  15           1   O
#  16        gene   O
#  17          in   O
#  18  transgenic   O
#  19        mice   O
#  20           .   O,               token tag
#  0       Interferons   O
#  1                 (   O
#  2              IFNs   O
#  3                 )   O
#  4               are   O
#  5              well   O
#  6             known   O
#  7              both   O
#  8                as   O
#  9         antiviral   O
#  10         proteins   O
#  11              and   O
#  12               as   O
#  13           potent   O
#  14       regulators   O
#  15               of   O
#  16             cell   O
#  17           growth   O
#  18              and   O
#  19  differentiation   O
#  20                .   O,           token tag
#  0            In   O
#  1          fact   O
#  2             ,   O
#  3          IFNs   O
#  4       inhibit   O
#  5        growth   O
#  6            of   O
#  7       various   O
#  8        normal   O
#  9           and   O
#  10  transformed   O
#  11         cell   O
#  12        types   O
#  13            .   O,             token tag
#  0      Previously   O
#  1               ,   O
#  2               a   O
#  3         nuclear   O
#  4          factor   O
#  5               ,   O
#  6           IRF-1   O
#  7               (   O
#  8      interferon   O
#  9      regulatory   O
#  10         factor   O
#  11              1   O
#  12              )   O
#  13              ,   O
#  14          which   O
#  15          binds   O
#  16             to   O
#  17           type   O
#  18              I   O
#  19            IFN   O
#  20            and   O
#  21           some   O
#  22  IFN-inducible   O
#  23           gene   O
#  24      promoters   O
#  25              ,   O
#  26            was   O
#  27     identified   O
#  28            and   O
#  29         cloned   O
#  30              .   O,               token tag
#  0             Since   O
#  1               the   O
#  2             IRF-1   O
#  3              gene   O
#  4                is   O
#  5              both   O
#  6             virus   O
#  7               and   O
#  8               IFN   O
#  9         inducible   O
#  10                ,   O
#  11               an   O
#  12       intriguing   O
#  13            issue   O
#  14               is   O
#  15           raised   O
#  16               as   O
#  17               to   O
#  18          whether   O
#  19              the   O
#  20            IRF-1   O
#  21             gene   O
#  22               is   O
#  23      functioning   O
#  24               in   O
#  25     IFN-mediated   O
#  26       regulation   O
#  27               of   O
#  28             cell   O
#  29           growth   O
#  30              and   O
#  31  differentiation   O
#  32                .   O,              token tag
#  0               In   O
#  1             this   O
#  2            study   O
#  3                ,   O
#  4               we   O
#  5        generated   O
#  6       transgenic   O
#  7             mice   O
#  8         carrying   O
#  9              the   O
#  10           human   O
#  11           IRF-1   O
#  12            gene   O
#  13          linked   O
#  14              to   O
#  15             the   O
#  16           human   O
#  17  immunoglobulin   O
#  18     heavy-chain   O
#  19        enhancer   O
#  20               .   O,           token tag
#  0            In   O
#  1           the   O
#  2    transgenic   O
#  3          mice   O
#  4             ,   O
#  5           all   O
#  6           the   O
#  7      lymphoid   O
#  8       tissues   O
#  9      examined   O
#  10       showed   O
#  11            a   O
#  12     dramatic   O
#  13    reduction   O
#  14           in   O
#  15          the   O
#  16       number   O
#  17           of   O
#  18            B   O
#  19  lymphocytes   O
#  20            (   O
#  21            B   O
#  22        cells   O
#  23            )   O
#  24            .   O,           token tag
#  0   Preparation   O
#  1           and   O
#  2      analysis   O
#  3            of   O
#  4          bone   O
#  5        marrow   O
#  6         cells   O
#  7          from   O
#  8           the   O
#  9      chimeric   O
#  10         mice   O
#  11    indicated   O
#  12         that   O
#  13          the   O
#  14         bone   O
#  15       marrow   O
#  16           is   O
#  17          the   O
#  18    effective   O
#  19         site   O
#  20          for   O
#  21     specific   O
#  22    depletion   O
#  23           of   O
#  24          the   O
#  25       B-cell   O
#  26   population   O
#  27            .   O,              token tag
#  0               In   O
#  1             fact   O
#  2                ,   O
#  3       transgenic   O
#  4             bone   O
#  5           marrow   O
#  6            cells   O
#  7       cocultured   O
#  8             with   O
#  9                a   O
#  10            bone   O
#  11  marrow-derived   O
#  12         stromal   O
#  13            cell   O
#  14            line   O
#  15        revealed   O
#  16              an   O
#  17         altered   O
#  18          B-cell   O
#  19      maturation   O
#  20         pattern   O
#  21               .   O,                   token tag
#  0        Identification   O
#  1                   and   O
#  2               cloning   O
#  3                    of   O
#  4                 TCF-1   O
#  5                     ,   O
#  6                     a   O
#  7                     T   O
#  8   lymphocyte-specific   O
#  9         transcription   O
#  10               factor   O
#  11           containing   O
#  12                    a   O
#  13    sequence-specific   O
#  14                  HMG   O
#  15                  box   O
#  16                    .   O,                   token tag
#  0           CD3-epsilon   O
#  1            expression   O
#  2                    is   O
#  3            controlled   O
#  4                    by   O
#  5                     a   O
#  6            downstream   O
#  7                     T   O
#  8   lymphocyte-specific   O
#  9              enhancer   O
#  10              element   O
#  11                    .   O,              token tag
#  0               We   O
#  1           report   O
#  2              the   O
#  3   identification   O
#  4               of   O
#  5                a   O
#  6                T   O
#  7    cell-specific   O
#  8    transcription   O
#  9           factor   O
#  10               ,   O
#  11           TCF-1   O
#  12               ,   O
#  13         binding   O
#  14              to   O
#  15            this   O
#  16         element   O
#  17               .   O,             token tag
#  0             The   O
#  1    multimerized   O
#  2     recognition   O
#  3           motif   O
#  4              of   O
#  5           TCF-1   O
#  6     constituted   O
#  7               a   O
#  8               T   O
#  9   cell-specific   O
#  10       enhancer   O
#  11              .   O,           token tag
#  0    Subsequent   O
#  1       cloning   O
#  2            of   O
#  3         TCF-1   O
#  4    identified   O
#  5         three   O
#  6        splice   O
#  7  alternatives   O
#  8             .   O,                   token tag
#  0                 TCF-1   O
#  1             contained   O
#  2                     a   O
#  3                single   O
#  4           DNA-binding   O
#  5                   HMG   O
#  6                   box   O
#  7                  most   O
#  8               closely   O
#  9               related   O
#  10                   to   O
#  11              similar   O
#  12                boxes   O
#  13                   in   O
#  14                  the   O
#  15             putative   O
#  16            mammalian   O
#  17      sex-determining   O
#  18                 gene   O
#  19                  SRY   O
#  20                  and   O
#  21                   in   O
#  22                  the   O
#  23  Schizosaccharomyces   O
#  24                pombe   O
#  25                   Mc   O
#  26               mating   O
#  27                 type   O
#  28                 gene   O
#  29                    .   O,          token tag
#  0        TCF-1   O
#  1         mRNA   O
#  2          was   O
#  3    expressed   O
#  4     uniquely   O
#  5           in   O
#  6            T   O
#  7  lymphocytes   O
#  8            .   O,              token tag
#  0             Upon   O
#  1   cotransfection   O
#  2             into   O
#  3            non-T   O
#  4            cells   O
#  5                ,   O
#  6            TCF-1   O
#  7            could   O
#  8    transactivate   O
#  9          through   O
#  10             its   O
#  11         cognate   O
#  12           motif   O
#  13               .   O,             token tag
#  0           These   O
#  1         results   O
#  2        identify   O
#  3           TCF-1   O
#  4              as   O
#  5               a   O
#  6               T   O
#  7   cell-specific   O
#  8   transcription   O
#  9          factor   O
#  10              ,   O
#  11          which   O
#  12          might   O
#  13           play   O
#  14              a   O
#  15           role   O
#  16             in   O
#  17            the   O
#  18  establishment   O
#  19             of   O
#  20            the   O
#  21         mature   O
#  22              T   O
#  23           cell   O
#  24      phenotype   O
#  25              .   O,             token tag
#  0         Nuclear   O
#  1          factor   O
#  2           kappa   O
#  3               B   O
#  4       activates   O
#  5   proenkephalin   O
#  6   transcription   O
#  7              in   O
#  8               T   O
#  9     lymphocytes   O
#  10              .   O,             token tag
#  0            Upon   O
#  1      activation   O
#  2               ,   O
#  3               T   O
#  4     lymphocytes   O
#  5      accumulate   O
#  6            high   O
#  7          levels   O
#  8              of   O
#  9             the   O
#  10   neuropeptide   O
#  11     enkephalin   O
#  12          which   O
#  13      correlate   O
#  14           with   O
#  15           high   O
#  16         levels   O
#  17             of   O
#  18  proenkephalin   O
#  19           mRNA   O
#  20             in   O
#  21            the   O
#  22          cells   O
#  23              .   O,              token tag
#  0             Here   O
#  1               we   O
#  2     investigated   O
#  3              the   O
#  4  transcriptional   O
#  5            basis   O
#  6              for   O
#  7            these   O
#  8          changes   O
#  9                .   O,             token tag
#  0             The   O
#  1   proenkephalin   O
#  2        promoter   O
#  3        contains   O
#  4               a   O
#  5        sequence   O
#  6    GGGGACGTCCCC   O
#  7               ,   O
#  8           named   O
#  9              B2   O
#  10              ,   O
#  11          which   O
#  12             is   O
#  13        similar   O
#  14             to   O
#  15            the   O
#  16          kappa   O
#  17              B   O
#  18       sequence   O
#  19    GGGGACTTTCC   O
#  20              ,   O
#  21            the   O
#  22        binding   O
#  23           site   O
#  24             of   O
#  25            the   O
#  26  transcription   O
#  27         factor   O
#  28        nuclear   O
#  29         factor   O
#  30              (   O
#  31             NF   O
#  32              )   O
#  33         -kappa   O
#  34              B   O
#  35              .   O,             token tag
#  0      Activation   O
#  1              of   O
#  2               T   O
#  3     lymphocytes   O
#  4         induces   O
#  5              an   O
#  6        NF-kappa   O
#  7          B-like   O
#  8         binding   O
#  9        activity   O
#  10             to   O
#  11            the   O
#  12             B2   O
#  13           site   O
#  14              ,   O
#  15    concomitant   O
#  16           with   O
#  17     activation   O
#  18             of   O
#  19            the   O
#  20  proenkephalin   O
#  21       promoter   O
#  22              .   O,              token tag
#  0        Mutations   O
#  1               at   O
#  2              the   O
#  3               B2   O
#  4             site   O
#  5          abolish   O
#  6             this   O
#  7  transcriptional   O
#  8       activation   O
#  9                .   O,              token tag
#  0              The   O
#  1         purified   O
#  2        homodimer   O
#  3                (   O
#  4              two   O
#  5             p50s   O
#  6                )   O
#  7               of   O
#  8              the   O
#  9      DNA-binding   O
#  10         subunit   O
#  11              of   O
#  12        NF-kappa   O
#  13               B   O
#  14           binds   O
#  15             the   O
#  16              B2   O
#  17            site   O
#  18              of   O
#  19   proenkephalin   O
#  20      relatively   O
#  21          better   O
#  22            than   O
#  23            does   O
#  24             the   O
#  25  heterotetramer   O
#  26               (   O
#  27             two   O
#  28            p65s   O
#  29            plus   O
#  30             two   O
#  31            p50s   O
#  32               )   O
#  33            form   O
#  34              of   O
#  35             the   O
#  36          factor   O
#  37               .   O,               token tag
#  0              Thus   O
#  1                 ,   O
#  2                it   O
#  3           appears   O
#  4              that   O
#  5               the   O
#  6   T-cell-specific   O
#  7        activation   O
#  8                of   O
#  9               the   O
#  10    proenkephalin   O
#  11         promoter   O
#  12               is   O
#  13         mediated   O
#  14               by   O
#  15         NF-kappa   O
#  16                B   O
#  17                .   O,               token tag
#  0           However   O
#  1                 ,   O
#  2                as   O
#  3          NF-kappa   O
#  4                 B   O
#  5                is   O
#  6        ubiquitous   O
#  7               and   O
#  8               the   O
#  9   transcriptional   O
#  10       activation   O
#  11          through   O
#  12              the   O
#  13               B2   O
#  14             site   O
#  15               is   O
#  16                T   O
#  17             cell   O
#  18         specific   O
#  19                ,   O
#  20              yet   O
#  21          another   O
#  22  T-cell-specific   O
#  23           factor   O
#  24            which   O
#  25       synergizes   O
#  26             with   O
#  27         NF-kappa   O
#  28                B   O
#  29           should   O
#  30               be   O
#  31       considered   O
#  32                .   O,                token tag
#  0         Expression   O
#  1                 of   O
#  2              c-jun   O
#  3                  ,   O
#  4                jun   O
#  5                  B   O
#  6                and   O
#  7                jun   O
#  8                  D   O
#  9    proto-oncogenes   O
#  10                in   O
#  11             human   O
#  12  peripheral-blood   O
#  13      granulocytes   O
#  14                 .   O,                token tag
#  0                 We   O
#  1               have   O
#  2              found   O
#  3               that   O
#  4           purified   O
#  5              human   O
#  6   peripheral-blood   O
#  7       granulocytes   O
#  8            express   O
#  9     constitutively   O
#  10       significant   O
#  11            levels   O
#  12                of   O
#  13   proto-oncogenes   O
#  14             c-jun   O
#  15                 ,   O
#  16               jun   O
#  17                 B   O
#  18               and   O
#  19               jun   O
#  20                 D   O
#  21              mRNA   O
#  22                 .   O,            token tag
#  0           Upon   O
#  1     functional   O
#  2     activation   O
#  3             of   O
#  4   granulocytes   O
#  5             by   O
#  6              4   O
#  7   beta-phorbol   O
#  8   12-myristate   O
#  9     13-acetate   O
#  10             (   O
#  11           PMA   O
#  12             )   O
#  13             ,   O
#  14           the   O
#  15        levels   O
#  16            of   O
#  17         c-jun   O
#  18             ,   O
#  19           jun   O
#  20             B   O
#  21           and   O
#  22           jun   O
#  23             D   O
#  24   transcripts   O
#  25          were   O
#  26     increased   O
#  27             .   O,         token tag
#  0         The   O
#  1       three   O
#  2         jun   O
#  3       genes   O
#  4      showed   O
#  5           a   O
#  6     similar   O
#  7        time   O
#  8      course   O
#  9          in   O
#  10      their   O
#  11  induction   O
#  12         by   O
#  13        PMA   O
#  14          ,   O
#  15    maximal   O
#  16       mRNA   O
#  17     levels   O
#  18      being   O
#  19    reached   O
#  20      after   O
#  21         60   O
#  22        min   O
#  23         of   O
#  24  induction   O
#  25          .   O,               token tag
#  0             These   O
#  1           results   O
#  2           suggest   O
#  3              that   O
#  4        expression   O
#  5                of   O
#  6             c-jun   O
#  7                 ,   O
#  8               jun   O
#  9                 B   O
#  10              and   O
#  11              jun   O
#  12                D   O
#  13            genes   O
#  14            might   O
#  15               be   O
#  16         involved   O
#  17               in   O
#  18         terminal   O
#  19      granulocyte   O
#  20  differentiation   O
#  21               or   O
#  22               in   O
#  23       regulating   O
#  24      granulocyte   O
#  25    functionality   O
#  26                .   O,                   token tag
#  0   Platelet-activating   O
#  1                factor   O
#  2               induces   O
#  3          phospholipid   O
#  4              turnover   O
#  5                     ,   O
#  6               calcium   O
#  7                  flux   O
#  8                     ,   O
#  9           arachidonic   O
#  10                 acid   O
#  11           liberation   O
#  12                    ,   O
#  13           eicosanoid   O
#  14           generation   O
#  15                    ,   O
#  16                  and   O
#  17             oncogene   O
#  18           expression   O
#  19                   in   O
#  20                    a   O
#  21                human   O
#  22                    B   O
#  23                 cell   O
#  24                 line   O
#  25                    .   O,                   token tag
#  0   Platelet-activating   O
#  1                factor   O
#  2                    is   O
#  3                     a   O
#  4                potent   O
#  5              mediator   O
#  6                    of   O
#  7                   the   O
#  8          inflammatory   O
#  9              response   O
#  10                    .   O,                   token tag
#  0               Studies   O
#  1                    of   O
#  2                   the   O
#  3               actions   O
#  4                    of   O
#  5   platelet-activating   O
#  6                factor   O
#  7                  have   O
#  8              centered   O
#  9                mainly   O
#  10               around   O
#  11          neutrophils   O
#  12                    ,   O
#  13            monocytes   O
#  14                    ,   O
#  15                  and   O
#  16            platelets   O
#  17                    .   O,                   token tag
#  0                    In   O
#  1                  this   O
#  2                report   O
#  3                    we   O
#  4                 begin   O
#  5                    to   O
#  6               uncover   O
#  7                   the   O
#  8             influence   O
#  9                    of   O
#  10  platelet-activating   O
#  11               factor   O
#  12                   on   O
#  13                    B   O
#  14          lymphocytes   O
#  15                    .   O,                        token tag
#  0                  Employing   O
#  1                        the   O
#  2            EBV-transformed   O
#  3                      human   O
#  4                          B   O
#  5                       cell   O
#  6                       line   O
#  7                     SKW6.4   O
#  8                          ,   O
#  9                         we   O
#  10               demonstrate   O
#  11                      that   O
#  12       platelet-activating   O
#  13                    factor   O
#  14             significantly   O
#  15                    alters   O
#  16                  membrane   O
#  17              phospholipid   O
#  18                metabolism   O
#  19                 indicated   O
#  20                        by   O
#  21                       the   O
#  22             incorporation   O
#  23                        of   O
#  24                       32P   O
#  25                      into   O
#  26       phosphatidylcholine   O
#  27                         ,   O
#  28      phosphatidylinositol   O
#  29                         ,   O
#  30                       and   O
#  31              phosphatidic   O
#  32                      acid   O
#  33                       but   O
#  34                       not   O
#  35             significantly   O
#  36                      into   O
#  37  phosphatidylethanolamine   O
#  38                        at   O
#  39            concentrations   O
#  40                   ranging   O
#  41                      from   O
#  42                        10   O
#  43                         (   O
#  44                        -9   O
#  45                         )   O
#  46                        to   O
#  47                        10   O
#  48                         (   O
#  49                        -6   O
#  50                         )   O
#  51                         M   O
#  52                         .   O,                        token         tag
#  0                        The           O
#  1                   inactive           O
#  2                  precursor           O
#  3                          ,           O
#  4   lyso-platelet-activating           O
#  5                     factor           O
#  6                          ,           O
#  7                         at           O
#  8                          a           O
#  9              concentration           O
#  10                        as           O
#  11                      high           O
#  12                        as           O
#  13                        10           O
#  14                         (           O
#  15                        -7           O
#  16                         )           O
#  17                         M           O
#  18                       had           O
#  19                        no  B-Negation
#  20                    effect  I-Negation
#  21                        on  I-Negation
#  22                       any  I-Negation
#  23                        of  I-Negation
#  24                       the  I-Negation
#  25                  membrane  I-Negation
#  26             phospholipids  I-Negation
#  27                         .           O,                        token tag
#  0                         We   O
#  1                       also   O
#  2                       show   O
#  3                       that   O
#  4        platelet-activating   O
#  5                     factor   O
#  6                       from   O
#  7                         10   O
#  8                          (   O
#  9                        -12   O
#  10                         )   O
#  11                        to   O
#  12                        10   O
#  13                         (   O
#  14                        -6   O
#  15                         )   O
#  16                         M   O
#  17                   induced   O
#  18                     rapid   O
#  19                       and   O
#  20               significant   O
#  21                 elevation   O
#  22                        in   O
#  23             intracellular   O
#  24                   calcium   O
#  25                    levels   O
#  26                         ,   O
#  27                   whereas   O
#  28  lyso-platelet-activating   O
#  29                    factor   O
#  30                       was   O
#  31                     again   O
#  32               ineffective   O
#  33                         .   O,                         token tag
#  0                          We   O
#  1                     further   O
#  2                 demonstrate   O
#  3                         the   O
#  4                      impact   O
#  5                          of   O
#  6         platelet-activating   O
#  7                      factor   O
#  8                     binding   O
#  9                          to   O
#  10                          B   O
#  11                      cells   O
#  12                         by   O
#  13                  measuring   O
#  14        platelet-activating   O
#  15                     factor   O
#  16                    induced   O
#  17                arachidonic   O
#  18                       acid   O
#  19                    release   O
#  20                        and   O
#  21  5-hydroxyeicosatetraenoic   O
#  22                       acid   O
#  23                 production   O
#  24                          .   O,                   token tag
#  0              Moreover   O
#  1                     ,   O
#  2   platelet-activating   O
#  3                factor   O
#  4                   was   O
#  5               capable   O
#  6                    of   O
#  7              inducing   O
#  8         transcription   O
#  9                    of   O
#  10                  the   O
#  11              nuclear   O
#  12      proto-oncogenes   O
#  13                c-fos   O
#  14                  and   O
#  15                c-jun   O
#  16                    .   O,                         token tag
#  0                     Finally   O
#  1                          we   O
#  2                    explored   O
#  3                         the   O
#  4                    possible   O
#  5                        role   O
#  6                          of   O
#  7   5-hydroxyeicosatetraenoic   O
#  8                        acid   O
#  9                          as   O
#  10                          a   O
#  11                  regulator   O
#  12                         of   O
#  13                arachidonic   O
#  14                       acid   O
#  15                 liberation   O
#  16              demonstrating   O
#  17                       that   O
#  18                 endogenous   O
#  19             5-lipoxygenase   O
#  20                   activity   O
#  21                  modulates   O
#  22        platelet-activating   O
#  23                     factor   O
#  24                    induced   O
#  25                arachidonic   O
#  26                       acid   O
#  27                    release   O
#  28                    perhaps   O
#  29                     acting   O
#  30                         at   O
#  31                        the   O
#  32                      level   O
#  33                         of   O
#  34              phospholipase   O
#  35                         A2   O
#  36                          .   O,                   token tag
#  0                    In   O
#  1               summary   O
#  2                     ,   O
#  3   platelet-activating   O
#  4                factor   O
#  5                    is   O
#  6                 shown   O
#  7                  here   O
#  8                    to   O
#  9                  have   O
#  10                    a   O
#  11               direct   O
#  12                  and   O
#  13             profound   O
#  14               effect   O
#  15                   on   O
#  16                    a   O
#  17                 pure   O
#  18                    B   O
#  19                 cell   O
#  20                 line   O
#  21                    .   O,           token tag
#  0             A   O
#  1         novel   O
#  2         HIV-1   O
#  3       isolate   O
#  4    containing   O
#  5   alterations   O
#  6     affecting   O
#  7           the   O
#  8      NF-kappa   O
#  9             B   O
#  10      element   O
#  11            .   O,           token tag
#  0         Three   O
#  1     molecular   O
#  2        clones   O
#  3            of   O
#  4         HIV-1   O
#  5             ,   O
#  6       derived   O
#  7          from   O
#  8             a   O
#  9        single   O
#  10      isolate   O
#  11            (   O
#  12          AL1   O
#  13            )   O
#  14            ,   O
#  15    exhibited   O
#  16     distinct   O
#  17  replicative   O
#  18          and   O
#  19   cytopathic   O
#  20   properties   O
#  21       during   O
#  22  propagation   O
#  23           in   O
#  24            a   O
#  25        human   O
#  26            T   O
#  27         cell   O
#  28         line   O
#  29            .   O,            token tag
#  0            The   O
#  1     phenotypic   O
#  2    differences   O
#  3       observed   O
#  4           were   O
#  5   attributable   O
#  6              ,   O
#  7             in   O
#  8          large   O
#  9           part   O
#  10             ,   O
#  11            to   O
#  12       changes   O
#  13     affecting   O
#  14           the   O
#  15         viral   O
#  16           LTR   O
#  17             .   O,            token tag
#  0     Nucleotide   O
#  1       sequence   O
#  2            and   O
#  3            PCR   O
#  4       analyses   O
#  5   demonstrated   O
#  6            the   O
#  7       presence   O
#  8             of   O
#  9          novel   O
#  10  duplications   O
#  11            or   O
#  12     deletions   O
#  13     involving   O
#  14           the   O
#  15      NF-kappa   O
#  16             B   O
#  17         motif   O
#  18             .   O,          token tag
#  0        These   O
#  1      changes   O
#  2           in   O
#  3          the   O
#  4     enhancer   O
#  5      element   O
#  6         were   O
#  7   identified   O
#  8           in   O
#  9          the   O
#  10    original   O
#  11         AL1   O
#  12       virus   O
#  13       stock   O
#  14           .   O,                      token tag
#  0               Subcloning   O
#  1                       of   O
#  2                      the   O
#  3                  variant   O
#  4                 NF-kappa   O
#  5                        B   O
#  6                 segments   O
#  7                     into   O
#  8               LTR-driven   O
#  9                      CAT   O
#  10              expression   O
#  11                 vectors   O
#  12               confirmed   O
#  13                       a   O
#  14             correlation   O
#  15                 between   O
#  16                promoter   O
#  17                activity   O
#  18                     and   O
#  19  replicative/cytopathic   O
#  20                capacity   O
#  21                       .   O,                    token tag
#  0  1,25-Dihydroxyvitamin   O
#  1                     D3   O
#  2               receptor   O
# ...
#  6           treatment   O
#  7                also   O
#  8           abolishes   O
#  9           induction   O
#  10                 of   O
#  11    chloramphenicol   O
#  12  acetyltransferase   O
#  13           activity   O
#  14                 in   O
#  15               Ar-5   O
#  16              cells   O
#  17        transfected   O
#  18               with   O
#  19                  a   O
#  20            plasmid   O
#  21         containing   O
#  22                the   O
#  23               IL-2   O
#  24           promoter   O
#  25             linked   O
#  26                 to   O
#  27               this   O
#  28           reporter   O
#  29               gene   O
#  30                  .   O,           token tag
#  0           The   O
#  1          IL-2   O
#  2      promoter   O
#  3      contains   O
#  4       binding   O
#  5         sites   O
#  6           for   O
#  7       nuclear   O
#  8       factors   O
#  9     including   O
#  10       NFAT-1   O
#  11            ,   O
#  12          Oct   O
#  13            ,   O
#  14     NF-kappa   O
#  15            B   O
#  16            ,   O
#  17          and   O
#  18         AP-1   O
#  19            ,   O
#  20        which   O
#  21          are   O
#  22          all   O
#  23  potentially   O
#  24    sensitive   O
#  25           to   O
#  26   activation   O
#  27           of   O
#  28          PKC   O
#  29            .   O,            token         tag
#  0             We           O
#  1           show           O
#  2           that           O
#  3      induction           O
#  4             of           O
#  5              a           O
#  6         trimer           O
#  7             of           O
#  8            the           O
#  9           NFAT           O
#  10           and           O
#  11           Oct           O
#  12         sites           O
#  13            is           O
#  14           not  B-Negation
#  15     sensitive  I-Negation
#  16            to  I-Negation
#  17       phorbol  I-Negation
#  18         ester  I-Negation
#  19     treatment  I-Negation
#  20             ,           O
#  21           and           O
#  22          that           O
#  23     mutations           O
#  24            in           O
#  25           the           O
#  26      NF-kappa           O
#  27             B           O
#  28          site           O
#  29          have           O
#  30            no  B-Negation
#  31        effect  I-Negation
#  32            on  I-Negation
#  33  inducibility  I-Negation
#  34            of  I-Negation
#  35           the  I-Negation
#  36          IL-2  I-Negation
#  37      promoter  I-Negation
#  38             .           O,          token tag
#  0           In   O
#  1     contrast   O
#  2            ,   O
#  3    mutations   O
#  4           in   O
#  5          the   O
#  6         AP-1   O
#  7         site   O
#  8      located   O
#  9           at   O
#  10        -150   O
#  11          bp   O
#  12      almost   O
#  13  completely   O
#  14    abrogate   O
#  15   induction   O
#  16          of   O
#  17         the   O
#  18        IL-2   O
#  19    promoter   O
#  20           ,   O
#  21         and   O
#  22  appearance   O
#  23          of   O
#  24          an   O
#  25   inducible   O
#  26     nuclear   O
#  27      factor   O
#  28     binding   O
#  29          to   O
#  30        this   O
#  31        site   O
#  32          is   O
#  33   sensitive   O
#  34          to   O
#  35         PKC   O
#  36   depletion   O
#  37           .   O,               token tag
#  0          Moreover   O
#  1                 ,   O
#  2   cotransfections   O
#  3              with   O
#  4             c-fos   O
#  5               and   O
#  6             c-jun   O
#  7        expression   O
#  8          plasmids   O
#  9          markedly   O
#  10          enhance   O
#  11        induction   O
#  12               of   O
#  13              the   O
#  14             IL-2   O
#  15         promoter   O
#  16               in   O
#  17        minimally   O
#  18       stimulated   O
#  19                T   O
#  20            cells   O
#  21                .   O,              token tag
#  0              Our   O
#  1          results   O
#  2         indicate   O
#  3             that   O
#  4              the   O
#  5             AP-1   O
#  6             site   O
#  7               at   O
#  8             -150   O
#  9               bp   O
#  10      represents   O
#  11               a   O
#  12           major   O
#  13               ,   O
#  14              if   O
#  15             not   O
#  16             the   O
#  17            only   O
#  18               ,   O
#  19            site   O
#  20              of   O
#  21             PKC   O
#  22  responsiveness   O
#  23              in   O
#  24             the   O
#  25            IL-2   O
#  26        promoter   O
#  27               .   O,               token tag
#  0       Interleukin   O
#  1         6-induced   O
#  2   differentiation   O
#  3                of   O
#  4                 a   O
#  5             human   O
#  6                 B   O
#  7              cell   O
#  8              line   O
#  9              into   O
#  10    IgM-secreting   O
#  11           plasma   O
#  12            cells   O
#  13               is   O
#  14         mediated   O
#  15               by   O
#  16            c-fos   O
#  17                .   O,               token tag
#  0               The   O
#  1              role   O
#  2                of   O
#  3               the   O
#  4     protooncogene   O
#  5             c-fos   O
#  6                in   O
#  7       interleukin   O
#  8                 (   O
#  9                IL   O
#  10                )   O
#  11        6-induced   O
#  12                B   O
#  13             cell   O
#  14  differentiation   O
#  15              was   O
#  16         assessed   O
#  17                .   O,           token tag
#  0     Treatment   O
#  1            of   O
#  2           SKW   O
#  3           6.4   O
#  4         cells   O
#  5          with   O
#  6            IL   O
#  7             6   O
#  8       induced   O
#  9             a   O
#  10    transient   O
#  11          and   O
#  12        early   O
#  13  stimulation   O
#  14           of   O
#  15        c-fos   O
#  16        sense   O
#  17         mRNA   O
#  18   expression   O
#  19            .   O,        token tag
#  0        The   O
#  1     effect   O
#  2   appeared   O
#  3     within   O
#  4         30   O
#  5        min   O
#  6        and   O
#  7   returned   O
#  8         to   O
#  9      basal   O
#  10    levels   O
#  11     after   O
#  12         2   O
#  13         h   O
#  14         .   O,                token         tag
#  0                The           O
#  1           addition           O
#  2                 of           O
#  3          antisense           O
#  4   oligonucleotides           O
#  5                 to           O
#  6              c-fos           O
#  7      significantly           O
#  8          inhibited           O
#  9                 IL           O
#  10         6-induced           O
#  11               IgM           O
#  12        production           O
#  13                by           O
#  14               SKW           O
#  15               6.4           O
#  16             cells           O
#  17                 (           O
#  18                 p           O
#  19              less           O
#  20              than           O
#  21             0.001           O
#  22                 )           O
#  23                 ,           O
#  24           whereas           O
#  25           control           O
#  26  oligonucleotides           O
#  27               had           O
#  28                no  B-Negation
#  29        inhibitory  I-Negation
#  30            effect  I-Negation
#  31                 .           O,               token tag
#  0             These   O
#  1           results   O
#  2          indicate   O
#  3              that   O
#  4        activation   O
#  5                of   O
#  6             c-fos   O
#  7                is   O
#  8          involved   O
#  9                in   O
#  10               IL   O
#  11        6-induced   O
#  12  differentiation   O
#  13               of   O
#  14              SKW   O
#  15              6.4   O
#  16            cells   O
#  17             into   O
#  18    IgM-secreting   O
#  19            cells   O
#  20                .   O,                       token tag
#  0                   Binding   O
#  1                        of   O
#  2                 erythroid   O
#  3                       and   O
#  4             non-erythroid   O
#  5                   nuclear   O
#  6                  proteins   O
#  7                        to   O
#  8                       the   O
#  9                  silencer   O
#  10                       of   O
#  11                      the   O
#  12                    human   O
#  13  epsilon-globin-encoding   O
#  14                     gene   O
#  15                        .   O,                   token tag
#  0                    To   O
#  1               clarify   O
#  2                   the   O
#  3             molecular   O
#  4            mechanisms   O
#  5              involved   O
#  6                    in   O
#  7                   the   O
#  8         developmental   O
#  9               control   O
#  10                   of   O
#  11  hemoglobin-encoding   O
#  12                genes   O
#  13                   we   O
#  14                 have   O
#  15                 been   O
#  16             studying   O
#  17                  the   O
#  18           expression   O
#  19                   of   O
#  20                these   O
#  21                genes   O
#  22                   in   O
#  23                human   O
#  24                cells   O
#  25                   in   O
#  26           continuous   O
#  27              culture   O
#  28                    .   O,                       token tag
#  0                        We   O
#  1                      have   O
#  2                previously   O
#  3                  reported   O
#  4                       the   O
#  5                  presence   O
#  6                        of   O
#  7                         a   O
#  8           transcriptional   O
#  9                   control   O
#  10                  element   O
#  11                     with   O
#  12                      the   O
#  13               properties   O
#  14                       of   O
#  15                        a   O
#  16                 silencer   O
#  17                extending   O
#  18                     from   O
#  19                     -392   O
#  20                       to   O
#  21                     -177   O
#  22                       bp   O
#  23                 relative   O
#  24                       to   O
#  25                      the   O
#  26                      cap   O
#  27                     site   O
#  28                       of   O
#  29                      the   O
#  30                    human   O
#  31  epsilon-globin-encoding   O
#  32                     gene   O
#  33                        [   O
#  34                      Cao   O
#  35                       et   O
#  36                      al.   O
#  37                        ,   O
#  38   Proc.Natl.Acad.Sci.USA   O
#  39                       86   O
#  40                        (   O
#  41                     1989   O
#  42                        )   O
#  43                5306-5309   O
#  44                        ]   O
#  45                        .   O,               token tag
#  0                We   O
#  1              also   O
#  2            showed   O
#  3              that   O
#  4              this   O
#  5          silencer   O
#  6               has   O
#  7          stronger   O
#  8        inhibitory   O
#  9          activity   O
#  10               in   O
#  11             HeLa   O
#  12            cells   O
#  13                ,   O
#  14               as   O
#  15         compared   O
#  16               to   O
#  17             K562   O
#  18            human   O
#  19  erythroleukemia   O
#  20            cells   O
#  21                .   O,                         token tag
#  0                       Using   O
#  1                    deletion   O
#  2                     mutants   O
#  3                         and   O
#  4                  cis-cloned   O
#  5                   synthetic   O
#  6   oligodeoxyribonucleotides   O
#  7                          in   O
#  8                   transient   O
#  9                  expression   O
#  10                     assays   O
#  11                          ,   O
#  12                 nucleotide   O
#  13                  sequences   O
#  14                responsible   O
#  15                        for   O
#  16                       this   O
#  17                     effect   O
#  18                       have   O
#  19                        now   O
#  20                       been   O
#  21                    further   O
#  22                  delimited   O
#  23                         to   O
#  24                         44   O
#  25                         bp   O
#  26                    located   O
#  27                       from   O
#  28                       -294   O
#  29                         to   O
#  30                       -251   O
#  31                         bp   O
#  32                          .   O,               token tag
#  0               Gel   O
#  1   electrophoresis   O
#  2          mobility   O
#  3             shift   O
#  4            assays   O
#  5               and   O
#  6            DNaseI   O
#  7      footprinting   O
#  8            assays   O
#  9       demonstrate   O
#  10             that   O
#  11            these   O
#  12         negative   O
#  13       regulatory   O
#  14        sequences   O
#  15              are   O
#  16       recognized   O
#  17      differently   O
#  18               by   O
#  19         proteins   O
#  20          present   O
#  21               in   O
#  22          nuclear   O
#  23         extracts   O
#  24         obtained   O
#  25             from   O
#  26             HeLa   O
#  27              and   O
#  28             K562   O
#  29            cells   O
#  30                .   O,        token tag
#  0        Two   O
#  1    binding   O
#  2   proteins   O
#  3        are   O
#  4   detected   O
#  5         in   O
#  6       K562   O
#  7    nuclear   O
#  8   extracts   O
#  9          ,   O
#  10     while   O
#  11      only   O
#  12       one   O
#  13        is   O
#  14     found   O
#  15        in   O
#  16  extracts   O
#  17      from   O
#  18      HeLa   O
#  19     cells   O
#  20         .   O,                       token tag
#  0                  Possible   O
#  1                mechanisms   O
#  2                        by   O
#  3                     which   O
#  4                     these   O
#  5                  proteins   O
#  6                       may   O
#  7                  regulate   O
#  8             transcription   O
#  9                        of   O
#  10                      the   O
#  11  epsilon-globin-encoding   O
#  12                     gene   O
#  13                       in   O
#  14                erythroid   O
#  15                      and   O
#  16            non-erythroid   O
#  17                    cells   O
#  18                      are   O
#  19                discussed   O
#  20                        .   O,           token tag
#  0  Gangliosides   O
#  1      suppress   O
#  2         tumor   O
#  3      necrosis   O
#  4        factor   O
#  5    production   O
#  6            in   O
#  7         human   O
#  8     monocytes   O
#  9             .   O,            token tag
#  0           Both   O
#  1         normal   O
#  2            and   O
#  3      malignant   O
#  4          cells   O
#  5        contain   O
#  6   gangliosides   O
#  7             as   O
#  8      important   O
#  9           cell   O
#  10      membrane   O
#  11  constituents   O
#  12          that   O
#  13             ,   O
#  14         after   O
#  15         being   O
#  16          shed   O
#  17             ,   O
#  18           may   O
#  19     influence   O
#  20         cells   O
#  21            of   O
#  22           the   O
#  23        immune   O
#  24        system   O
#  25             .   O,            token tag
#  0             We   O
#  1           have   O
#  2        studied   O
#  3            the   O
#  4         impact   O
#  5             of   O
#  6   gangliosides   O
#  7             on   O
#  8            the   O
#  9     expression   O
#  10            of   O
#  11           TNF   O
#  12            in   O
#  13         blood   O
#  14     monocytes   O
#  15           and   O
#  16            in   O
#  17           the   O
#  18     monocytic   O
#  19          cell   O
#  20          line   O
#  21          Mono   O
#  22           Mac   O
#  23             6   O
#  24             .   O, ...]

# %%
data_concat = pd.concat(negation_bio,keys = data.sid.to_list())
data_concat.reset_index(inplace=True)

# %%
data_concat.iloc[50:100,:]
# Out:
#    level_0  level_1            token         tag
# 50    S1.3        1         mobility           O
# 51    S1.3        2            shift           O
# 52    S1.3        3           assays           O
# 53    S1.3        4              and           O
# 54    S1.3        5     Southwestern           O
# 55    S1.3        6         blotting           O
# 56    S1.3        7      experiments           O
# 57    S1.3        8             were           O
# 58    S1.3        9             used           O
# 59    S1.3       10               to           O
# 60    S1.3       11           detect           O
# 61    S1.3       12              the           O
# 62    S1.3       13          binding           O
# 63    S1.3       14               of           O
# 64    S1.3       15         cellular           O
# 65    S1.3       16  transactivation           O
# 66    S1.3       17           factor           O
# 67    S1.3       18            NF-KB           O
# 68    S1.3       19               to           O
# 69    S1.3       20              the           O
# 70    S1.3       21           double           O
# 71    S1.3       22        repeat-KB           O
# 72    S1.3       23         enhancer           O
# 73    S1.3       24         sequence           O
# 74    S1.3       25          located           O
# 75    S1.3       26               in           O
# 76    S1.3       27              the           O
# 77    S1.3       28             long           O
# 78    S1.3       29         terminal           O
# 79    S1.3       30           repeat           O
# 80    S1.3       31                .           O
# 81    S1.4        0              PMA           O
# 82    S1.4        1        treatment           O
# 83    S1.4        2                ,           O
# 84    S1.4        3              and           O
# 85    S1.4        4              not  B-Negation
# 86    S1.4        5         retinoic  I-Negation
# 87    S1.4        6             acid  I-Negation
# 88    S1.4        7        treatment  I-Negation
# 89    S1.4        8               of  I-Negation
# 90    S1.4        9              the  I-Negation
# 91    S1.4       10             U937  I-Negation
# 92    S1.4       11            cells  I-Negation
# 93    S1.4       12             acts           O
# 94    S1.4       13               in           O
# 95    S1.4       14         inducing           O
# 96    S1.4       15            NF-KB           O
# 97    S1.4       16       expression           O
# 98    S1.4       17               in           O
# 99    S1.4       18              the           O

# %%
def train_test_dev_split(pmid, p_train = 0.7, p_test = 0.15, r1 = 42, r2 = 100):
    """
    split the id list into trian test dev list

    pmid: list list of id for this func
    p_train: train set per
    p_test: test set per
    r1: random state for first split
    r2: random state for second split

    return:
        train_pmid: list for train
        test_pmid: list for test
        dev_pmid: list for dev
    """
    train_pmid, other = train_test_split(pmid, test_size = (1 - p_train), random_state = r1)
    test_pmid, dev_pmid = train_test_split(other, test_size = p_test/(1 - p_train), random_state = r2)
    return train_pmid, test_pmid, dev_pmid

# This function just randomly splits the data into training, dev, and test

# %%
train_data, test_data, dev_data = train_test_dev_split(data)

# %%
#C:\Users\Sri\Google Drive\Data Science\Python\Data_formats\bio_xml_parse\bio_output\negations
def output_bio(name, sample):
    out_file = name + '.txt'
    for i in sample:
    #     print(i)
        temp = data_concat[data_concat.level_0 == i][['token','tag']]
    #     temp.word = temp.word.apply(lambda x: x.lower())
        temp.to_csv(out_file, header = None, index = None,
                               sep = '\t', mode = 'a')
    #     print(temp)
        # add a new line after each sentence
        with open(out_file, 'a') as f:
            f.write('\n')
    #     print('\n')
    return 'done'

# %%
output_bio('output', data['sid'].to_list())

# %%
#extract_bio(data, ['neg_scopes'])

# %%
data_result = extract_bio(data, ['neg_scopes'])

# %%
len(data_result)

# %%
data_result

# %%
data_concat = pd.concat(data_result, keys = data.id.to_list())
data_concat.reset_index(inplace=True)
data_concat.head()

# %% [markdown]
# **Split the data into train, dev, test**

# %%
#train_data, test_data, dev_data = train_test_dev_split(data)
# Uncomment above & comment below, if the final data to be bio tagged is read directly and has not already been split.
train_data = new_train
dev_data = new_dev
test_data = new_test

# %%
id_ls = list(data_concat.level_0.unique())

# %%
len(id_ls)

# %% [markdown]
# **Output the bio tagged data**

# %%
# Enter the correct path below, where the BIO files need to be written

# %%
def output_bio(name, sample):
      
    out_file = 'data/ner/new_golden/' + name +'_actor.txt'
    if(path.exists(out_file)):
        print ('BIO files already exist')
        return 'done'
    else:
        for i in sample:
        #     print(i)
            temp = data_concat[data_concat.level_0 == i][['word','pos','actor']]
        #     temp.word = temp.word.apply(lambda x: x.lower())
            temp.to_csv(out_file, header = None, index = None,
                                   sep = '\t', mode = 'a')
        #     print(temp)
            # add a new line after each sentence
            with open(out_file, 'a') as f:
                f.write('\n')
        #     print('\n')
    return 'done'

# %%
# below code writes the output into text files with "name_actor": Ex: "train_actor".txt 
# dont run them twice, since the files will be appended

# %%
output_bio('train', train_data['id'].to_list())

# %%
output_bio('dev', dev_data['id'].to_list())

# %%
output_bio('test', test_data['id'].to_list())
